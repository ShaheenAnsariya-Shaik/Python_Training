# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
d1.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
d1
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
# ...

# %%
d2=pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %%
d2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
d9=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv',names=['c1','c2'])

# %%
d9.head()
# Out:
#                                                                                                                                           c1  \
# Indicator                         PUBLISH STATES Year WHO region World Bank income group Country Sex        Display Value Numeric  Low  High
# Life expectancy at birth (years)  Published      1990 Europe     High-income             Andorra Both sexes 77            77.00000 NaN   NaN
#                                                  2000 Europe     High-income             Andorra Both sexes 80            80.00000 NaN   NaN
# Life expectancy at age 60 (years) Published      2012 Europe     High-income             Andorra Female     28            28.00000 NaN   NaN
#                                                  2000 Europe     High-income             Andorra Both sexes 23            23.00000 NaN   NaN
#
# ...

# %%
d9=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv',skiprows=[0,2,4],names=['c1','c2'])

# %%
d9.head()
# Out:
#                                                                                                                                 c1  \
# Life expectancy at birth (years)  Published 1990 Europe                High-income Andorra              Both sexes 77 77.0 NaN NaN
# Life expectancy at age 60 (years) Published 2012 Europe                High-income Andorra              Female     28 28.0 NaN NaN
# Life expectancy at birth (years)  Published 2012 Eastern Mediterranean High-income United Arab Emirates Female     78 78.0 NaN NaN
#                                             2000 Americas              High-income Antigua and Barbuda  Male       72 72.0 NaN NaN
# Life expectancy at age 60 (years) Published 1990 Americas              High-income Antigua and Barbuda  Male       17 17.0 NaN NaN
#
#                                                                                                                                 c2
# ...

# %%
import os

# %%
os.chdir('C:/Users/sansariya/Documents')

# %%
d=pd.read_excel('ex1.xlsx')

# %%
d
# Out:
#       names  count
# 0   shaheen      7
# 1  ansariya      9
# 2     shaik      5

# %%
d.to_excel('new_d.xlsx')

# %%
d.to_csv('new_csv.xlsx')

# %%
gd=pd.read_csv('googleplaystore.csv')

# %%
gd.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
gd.Rating.dtype
# Out:
# dtype('float64')

# %%
gd.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
gd.shape
# Out:
# (10841, 13)

# %%
gd.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
gd.loc[2:5,['App','Size']]
# Out:
#                                                  App  Size
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  8.7M
# 3                              Sketch - Draw & Paint   25M
# 4              Pixel Draw - Number Art Coloring Book  2.8M
# 5                         Paper flowers instructions  5.6M

# %%
gd.iloc[2:5,[2,3]]
# Out:
#    Rating Reviews
# 2     4.7   87510
# 3     4.5  215644
# 4     4.3     967

# %%
gd.iloc[:,3:9]
# Out:
#       Reviews                Size     Installs  Type Price Content Rating
# 0         159                 19M      10,000+  Free     0       Everyone
# 1         967                 14M     500,000+  Free     0       Everyone
# 2       87510                8.7M   5,000,000+  Free     0       Everyone
# 3      215644                 25M  50,000,000+  Free     0           Teen
# 4         967                2.8M     100,000+  Free     0       Everyone
# ...       ...                 ...          ...   ...   ...            ...
# 10836      38                 53M       5,000+  Free     0       Everyone
# 10837       4                3.6M         100+  Free     0       Everyone
# 10838       3                9.5M       1,000+  Free     0       Everyone
# 10839     114  Varies with device       1,000+  Free     0     Mature 17+
# 10840  398307                 19M  10,000,000+  Free     0       Everyone
#
# [10841 rows x 6 columns]

# %%
gd=pd.read_csv('googleplaystore.csv')

# %%
gd.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
gd[(gd.Rating > 3) & (gd.Reviews > 10000)]
# Out:
#                                                      App        Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 7                                       Infinite Painter  ART_AND_DESIGN
# 8                                   Garden Coloring Book  ART_AND_DESIGN
# 10                               Text on Photo - Fonteee  ART_AND_DESIGN
# ...                                                  ...             ...
# 10797                              Fuel Rewards® program       LIFESTYLE
# 10803                       Fatal Raid - No.1 Mobile FPS            GAME
# 10809              Castle Clash: RPG War and Strategy FR          FAMILY
# 10826          Frim: get new friends on local chat rooms          SOCIAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# ...

# %%
gd.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.193338  4.443887e+05
# std       0.537431  2.927728e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.479800e+04
# max      19.000000  7.815831e+07

# %%
gd[((gd.Rating > 3) & (gd.Reviews > 10000)) | (gd.Category=='ART_AND_DESIGN')]
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10797                              Fuel Rewards® program       LIFESTYLE
# 10803                       Fatal Raid - No.1 Mobile FPS            GAME
# 10809              Castle Clash: RPG War and Strategy FR          FAMILY
# 10826          Frim: get new friends on local chat rooms          SOCIAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# ...

# %%
gd[gd['Category'].isin(['ART_AND_DESIGN'])]
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 7174                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8679                                       Dp for girls  ART_AND_DESIGN
# 8712             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8871                             Test Application DT 02  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating  Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
gd[((gd.Rating > 3) & (~gd.Reviews > 10000)) | gd['Category'].isin(['ART_AND_DESIGN'])]
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 7174                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8679                                       Dp for girls  ART_AND_DESIGN
# 8712             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8871                             Test Application DT 02  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating  Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
gd.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
gd.rename(columns={'App':'App_1'})
# Out:
#                                                    App_1             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import os
os.chdir('C:/Users/sansariya/Documents/AI_Acadamy_Training/python_AI_Acamady')
l=pd.read_csv('left.csv')
r=pd.read_csv('right.csv')

# %%
l=pd.read_csv('left.csv')
r=pd.read_csv('right.csv')

# %%
l
# Out:
#    age students
# 0   20        A
# 1   18        B
# 2   19        C
# 3   20        D
# 4   21        E
# 5   22        F

# %%
r
# Out:
#   students  marks
# 0        A     30
# 1        B     32
# 2        C     33
# 3        D     39

# %%
ij=pd.merge(l,r,on='students')

# %%
ij
# Out:
#    age students  marks
# 0   20        A     30
# 1   18        B     32
# 2   19        C     33
# 3   20        D     39

# %%
ij=pd.merge(l,r,on='students',how='left')

# %%
ij
# Out:
#    age students  marks
# 0   20        A   30.0
# 1   18        B   32.0
# 2   19        C   33.0
# 3   20        D   39.0
# 4   21        E    NaN
# 5   22        F    NaN

# %%
g=gd[['Category','Type','Reviews','Rating']]

# %%
g.head()
# Out:
#          Category  Type  Reviews  Rating
# 0  ART_AND_DESIGN  Free      159     4.1
# 1  ART_AND_DESIGN  Free      967     3.9
# 2  ART_AND_DESIGN  Free    87510     4.7
# 3  ART_AND_DESIGN  Free   215644     4.5
# 4  ART_AND_DESIGN  Free      967     4.3

# %%
#numpy

# %%
a=[1,2,3,4.5,6.1]
np_a=np.array(a)

# %%
np_a
# Out:
# array([1. , 2. , 3. , 4.5, 6.1])

# %%
np_a.ndim
# Out:
# 1

# %%
np_a.shape
# Out:
# (5,)

# %%
a
np_a
# Out:
# array([1. , 2. , 3. , 4.5, 6.1])

# %%
a
# Out:
# [1, 2, 3, 4.5, 6.1]

# %%
import matplotlib.pyplot as plt
plt.scatter(a,np_a,c='r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('example')
plt.show()

# %%
import numpy as np
x=np.arrange(0,5)
y=np.arrange(6,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-cd3ef63c385d> in <module>
#       1 import numpy as np
# ----> 2 x=np.arrange(0,5)
#       3 y=np.arrange(6,10)
#
# ~\Anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     301                 return Tester
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#     305
#
# AttributeError: module 'numpy' has no attribute 'arrange'
